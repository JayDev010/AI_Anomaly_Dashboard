# %% [markdown]
# # Log Analysis and Anomaly Detection
#
# This notebook processes log data to detect anomalies based on time differences and country changes.

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd

# %% [markdown]
# ## 2. Load Data

# %%
# Load data (keep all columns)
df = pd.read_csv('zt_logs.csv')

# %% [markdown]
# ## 3. Process Timestamps

# %%
# Ensure timestamp exists: create from date+time if necessary, otherwise parse existing timestamp
if 'timestamp' not in df.columns and {'date', 'time'}.issubset(df.columns):
    df['timestamp'] = pd.to_datetime(df['date'].astype(str) + ' ' + df['time'].astype(str), errors='coerce')
else:
    df['timestamp'] = pd.to_datetime(df['timestamp'], errors='coerce')

# %% [markdown]
# ## 4. Sort Data

# %%
# Sort by user then timestamp (keeps all columns)
df = df.sort_values(by=['user', 'timestamp'], ascending=[True, True]).reset_index(drop=True)

# %% [markdown]
# ## 5. Compute Time Differences

# %%
# Compute time diff within each user (seconds and minutes)
df['time_diff_seconds'] = df.groupby('user')['timestamp'].diff().dt.total_seconds()
df['time_diff_minutes'] = df['time_diff_seconds'] / 60

# %% [markdown]
# ## 6. Detect Country Changes

# %%
# Get previous country for same user to detect change
df['prev_country'] = df.groupby('user')['country'].shift(1)

# %% [markdown]
# ## 7. Anomaly Detection

# %%
# Anomaly rule: time_diff_minutes < 180 AND country changed (prev_country != country)
df['is_anomaly'] = (
    df['time_diff_minutes'].notna()  # exclude first events which are NaN
    & (df['time_diff_minutes'] < 60)
    & (df['country'] != df['prev_country'])
).astype(int)

# %% [markdown]
# ## 8. Clean Up Helper Columns

# %%
# The prev_country helper column is optional; drop it if you don't want it saved:
df = df.drop(columns=['prev_country'])

# %% [markdown]
# ## 9. Preview Results

# %%
df.head(15)
# Out:
#              timestamp     user        role  device_id device_trust country  \
# 0  2025-10-10 03:35:18  user001  contractor  device022    untrusted      US
# 1  2025-10-10 12:58:46  user001    employee  device071      trusted      UK
# 2  2025-10-10 12:58:49  user001    employee  device016      trusted      UK
# 3  2025-10-10 12:59:01  user001    employee  device074      trusted      SG
# 4  2025-10-10 13:12:38  user001    employee  device007      trusted      US
# 5  2025-10-10 13:24:32  user001  contractor  device025      trusted      UK
# 6  2025-10-10 13:25:08  user001    employee  device051    untrusted      IN
# 7  2025-10-10 13:26:07  user001    employee  device046      trusted      IN
# 8  2025-10-10 13:37:20  user001    employee  device017      trusted      DE
# 9  2025-10-10 13:50:59  user001       admin  device030      trusted      SG
# 10 2025-10-10 14:24:48  user001    employee  device016      trusted      IN
# 11 2025-10-10 14:58:07  user001    employee  device038      trusted      IN
# 12 2025-10-10 15:24:24  user001  contractor  device039      trusted      DE
# 13 2025-10-10 15:26:14  user001    employee  device024      trusted      UK
# 14 2025-10-10 15:42:08  user001  contractor  device023      trusted      UK
#
#       lat     lon     resource  action   result    mfa  is_anomaly  \
# 0   37.77 -122.41        email   login  success  False           0
# 1   51.50   -0.12          vpn  access  success   True           0
# 2   51.50   -0.12    hr_portal  logout  success   True           0
# 3    1.35  103.82  finance_app  access  success  False           1
# 4   37.77 -122.41        email  access  success   True           1
# 5   51.50   -0.12          vpn  access  success  False           1
# 6   19.07   72.87          vpn   login  success   True           1
# 7   19.07   72.87  finance_app  logout  success  False           0
# 8   52.52   13.40        email  logout  success   True           1
# 9    1.35  103.82     dev_repo  access  success  False           1
# 10  19.07   72.87  finance_app  logout  success   True           1
# 11  19.07   72.87        email  access  success   True           0
# 12  52.52   13.40        email   login  success   True           1
# 13  51.50   -0.12    hr_portal  logout  success   True           1
# 14  51.50   -0.12        email  logout  success  False           0
#
#     time_diff_seconds  time_diff_minutes
# 0                 NaN                NaN
# 1             33808.0         563.466667
# 2                 3.0           0.050000
# 3                12.0           0.200000
# 4               817.0          13.616667
# 5               714.0          11.900000
# 6                36.0           0.600000
# 7                59.0           0.983333
# 8               673.0          11.216667
# 9               819.0          13.650000
# 10             2029.0          33.816667
# 11             1999.0          33.316667
# 12             1577.0          26.283333
# 13              110.0           1.833333
# 14              954.0          15.900000

# %%
# Quick preview
print(df[['user', 'timestamp', 'time_diff_minutes', 'country', 'is_anomaly']].head(15))
# Out:
#        user           timestamp  time_diff_minutes country  is_anomaly
# 0   user001 2025-10-10 03:35:18                NaN      US           0
# 1   user001 2025-10-10 12:58:46         563.466667      UK           0
# 2   user001 2025-10-10 12:58:49           0.050000      UK           0
# 3   user001 2025-10-10 12:59:01           0.200000      SG           1
# 4   user001 2025-10-10 13:12:38          13.616667      US           1
# 5   user001 2025-10-10 13:24:32          11.900000      UK           1
# 6   user001 2025-10-10 13:25:08           0.600000      IN           1
# 7   user001 2025-10-10 13:26:07           0.983333      IN           0
# 8   user001 2025-10-10 13:37:20          11.216667      DE           1
# 9   user001 2025-10-10 13:50:59          13.650000      SG           1
# 10  user001 2025-10-10 14:24:48          33.816667      IN           1
# 11  user001 2025-10-10 14:58:07          33.316667      IN           0
# 12  user001 2025-10-10 15:24:24          26.283333      DE           1
# 13  user001 2025-10-10 15:26:14           1.833333      UK           1
# 14  user001 2025-10-10 15:42:08          15.900000      UK           0

# %% [markdown]
# ## 10. Save Results

# %%
# Save result (keeps all original columns + new ones appended)
df.to_csv('zt_logs_with_time_diff_and_anomaly.csv', index=False)
